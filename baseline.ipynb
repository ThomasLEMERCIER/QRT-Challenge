# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import xgboost as xgb

# %%
from src.dataset import load_data
from src.preprocessing import impute_missing_values, split_data, remove_name_columns, encode_target_variable

x, y = load_data()
x = remove_name_columns(x)
y = encode_target_variable(y)
(x_train, y_train), (x_val, y_val), (x_test, y_test) = split_data(x, y)

x_train, imputer = impute_missing_values(x_train)
x_val, _ = impute_missing_values(x_val, imputer=imputer)
x_test, _ = impute_missing_values(x_test, imputer=imputer)

# %%
xgb_params = {
    "booster": "gbtree",
    "device": "cpu",

    "eta": 0.3,
    "gamma": 0,
    "max_depth": 6,
    "lambda": 1,
    "alpha": 0,

    "objective": "multi:softmax",
    "num_class": 3,
    "eval_metric": "merror",
}

num_boost_round = 1000
early_stopping_rounds = 100

dtrain = xgb.DMatrix(x_train, label=y_train)
dval = xgb.DMatrix(x_val, label=y_val)
dtest = xgb.DMatrix(x_test, label=y_test)

evals = [(dtrain, "train"), (dval, "val")]

bst = xgb.train(xgb_params, dtrain, num_boost_round=num_boost_round, evals=evals, early_stopping_rounds=early_stopping_rounds)
# Out:
# [0]	train-merror:0.43884	val-merror:0.51498
# [1]	train-merror:0.41242	val-merror:0.51701
# [2]	train-merror:0.39350	val-merror:0.52209
# [3]	train-merror:0.37851	val-merror:0.51651
# [4]	train-merror:0.36289	val-merror:0.51041
# [5]	train-merror:0.34777	val-merror:0.51498
# [6]	train-merror:0.32643	val-merror:0.51092
# [7]	train-merror:0.30814	val-merror:0.50940
# [8]	train-merror:0.28820	val-merror:0.50889
# [9]	train-merror:0.26648	val-merror:0.50990
# [10]	train-merror:0.24565	val-merror:0.50635
# [11]	train-merror:0.22952	val-merror:0.50787
# [12]	train-merror:0.21351	val-merror:0.51397
# [13]	train-merror:0.19916	val-merror:0.50787
# [14]	train-merror:0.18506	val-merror:0.51295
# [15]	train-merror:0.17033	val-merror:0.50787
# [16]	train-merror:0.15902	val-merror:0.50990
# [17]	train-merror:0.14721	val-merror:0.51041
# [18]	train-merror:0.13565	val-merror:0.51295
# [19]	train-merror:0.12676	val-merror:0.50838
# [20]	train-merror:0.11482	val-merror:0.51651
# [21]	train-merror:0.10822	val-merror:0.51955
# [22]	train-merror:0.10161	val-merror:0.52260
# [23]	train-merror:0.09221	val-merror:0.52209
# [24]	train-merror:0.08383	val-merror:0.52768
# [25]	train-merror:0.07596	val-merror:0.51549
# [26]	train-merror:0.06770	val-merror:0.51549
# [27]	train-merror:0.06008	val-merror:0.51498
# [28]	train-merror:0.05385	val-merror:0.51193
# [29]	train-merror:0.05004	val-merror:0.50990
# [30]	train-merror:0.04407	val-merror:0.51092
# [31]	train-merror:0.03988	val-merror:0.51600
# [32]	train-merror:0.03607	val-merror:0.51854
# [33]	train-merror:0.03226	val-merror:0.51701
# [34]	train-merror:0.02794	val-merror:0.51752
# [35]	train-merror:0.02540	val-merror:0.51955
# [36]	train-merror:0.02426	val-merror:0.52158
# [37]	train-merror:0.02007	val-merror:0.52412
# [38]	train-merror:0.01893	val-merror:0.52006
# [39]	train-merror:0.01778	val-merror:0.52158
# [40]	train-merror:0.01626	val-merror:0.52108
# [41]	train-merror:0.01372	val-merror:0.51600
# [42]	train-merror:0.01232	val-merror:0.51701
# [43]	train-merror:0.01143	val-merror:0.51955
# [44]	train-merror:0.01042	val-merror:0.51651
# [45]	train-merror:0.00927	val-merror:0.51549
# [46]	train-merror:0.00889	val-merror:0.51600
# [47]	train-merror:0.00775	val-merror:0.51752
# [48]	train-merror:0.00660	val-merror:0.51397
# [49]	train-merror:0.00572	val-merror:0.51803
# [50]	train-merror:0.00508	val-merror:0.52006
# [51]	train-merror:0.00508	val-merror:0.52362
# [52]	train-merror:0.00406	val-merror:0.52158
# [53]	train-merror:0.00419	val-merror:0.52362
# [54]	train-merror:0.00368	val-merror:0.52158
# [55]	train-merror:0.00330	val-merror:0.51905
# [56]	train-merror:0.00318	val-merror:0.52514
# [57]	train-merror:0.00254	val-merror:0.52819
# [58]	train-merror:0.00165	val-merror:0.52362
# [59]	train-merror:0.00114	val-merror:0.52920
# [60]	train-merror:0.00102	val-merror:0.53022
# [61]	train-merror:0.00076	val-merror:0.52920
# [62]	train-merror:0.00076	val-merror:0.53530
# [63]	train-merror:0.00076	val-merror:0.52971
# [64]	train-merror:0.00089	val-merror:0.52920
# [65]	train-merror:0.00089	val-merror:0.53073
# [66]	train-merror:0.00076	val-merror:0.52920
# [67]	train-merror:0.00051	val-merror:0.53022
# [68]	train-merror:0.00038	val-merror:0.53276
# [69]	train-merror:0.00038	val-merror:0.53123
# [70]	train-merror:0.00038	val-merror:0.52971
# [71]	train-merror:0.00038	val-merror:0.52819
# [72]	train-merror:0.00038	val-merror:0.53225
# [73]	train-merror:0.00038	val-merror:0.52819
# [74]	train-merror:0.00038	val-merror:0.52514
# [75]	train-merror:0.00025	val-merror:0.52514
# [76]	train-merror:0.00000	val-merror:0.52463
# [77]	train-merror:0.00000	val-merror:0.52717
# [78]	train-merror:0.00000	val-merror:0.52463
# [79]	train-merror:0.00000	val-merror:0.52768
# [80]	train-merror:0.00000	val-merror:0.52565
# [81]	train-merror:0.00000	val-merror:0.52412
# [82]	train-merror:0.00000	val-merror:0.52158
# [83]	train-merror:0.00000	val-merror:0.51955
# [84]	train-merror:0.00000	val-merror:0.52006
# [85]	train-merror:0.00000	val-merror:0.52412
# [86]	train-merror:0.00000	val-merror:0.52362
# [87]	train-merror:0.00000	val-merror:0.52514
# [88]	train-merror:0.00000	val-merror:0.52514
# [89]	train-merror:0.00000	val-merror:0.52768
# [90]	train-merror:0.00000	val-merror:0.52514
# [91]	train-merror:0.00000	val-merror:0.52717
# [92]	train-merror:0.00000	val-merror:0.52768
# [93]	train-merror:0.00000	val-merror:0.52869
# [94]	train-merror:0.00000	val-merror:0.52717
# [95]	train-merror:0.00000	val-merror:0.52768
# [96]	train-merror:0.00000	val-merror:0.52565
# [97]	train-merror:0.00000	val-merror:0.52869
# [98]	train-merror:0.00000	val-merror:0.52616
# [99]	train-merror:0.00000	val-merror:0.52666
# [100]	train-merror:0.00000	val-merror:0.52717
# [101]	train-merror:0.00000	val-merror:0.53225
# [102]	train-merror:0.00000	val-merror:0.53479
# [103]	train-merror:0.00000	val-merror:0.53123
# [104]	train-merror:0.00000	val-merror:0.53377
# [105]	train-merror:0.00000	val-merror:0.53428
# [106]	train-merror:0.00000	val-merror:0.53022
# [107]	train-merror:0.00000	val-merror:0.53377
# [108]	train-merror:0.00000	val-merror:0.53174
# [109]	train-merror:0.00000	val-merror:0.52920
# [110]	train-merror:0.00000	val-merror:0.52819

# %%
from src.evaluate import evaluate_model

acc_val = evaluate_model(bst, dval, y_val)
acc_test = evaluate_model(bst, dtest, y_test)

print(f"Validation accuracy: {acc_val:.4f}")
print(f"Test accuracy: {acc_test:.4f}")
# Out:
# Validation accuracy: 0.4901
# Test accuracy: 0.4807

# %%
from src.postprocessing import  compute_prediction, save_predictions

x_test = load_data(train=False)

x_test = remove_name_columns(x_test)
x_test, _ = impute_missing_values(x_test, imputer=imputer)

dtest = xgb.DMatrix(x_test)

y_pred = bst.predict(dtest, iteration_range=(0, bst.best_iteration))
predictions = compute_prediction(y_pred, x_test)

save_predictions(predictions, "xgboost.csv")
